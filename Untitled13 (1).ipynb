# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
from huggingface_hub import login
login()
#Token: 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

# %%
import os, json, numpy as np, pandas as pd, warnings
warnings.filterwarnings("ignore")

# ----------------------------
# Paths
# ----------------------------
emb_path   = "metric_name_embeddings.npy"
names_path = "metric_names.json"
train_path = "train_data.json"
test_path  = "test_data.json"
val_path   = "synthetic_data_5500_scores_0_8.json"

# ----------------------------
# Load base data
# ----------------------------
with open(names_path, "r", encoding="utf-8") as f:
    metric_name_list = json.load(f)  # list aligned with metric_emb rows

metric_emb = np.load(emb_path)
train_df = pd.read_json(train_path, lines=False)
test_df  = pd.read_json(test_path,  lines=False)
val_df   = pd.read_json(val_path,   lines=False)

print("Original Train shape:", train_df.shape)
print("Test shape          :", test_df.shape)
print("Synthetic data shape:", val_df.shape)

print("Train columns:", list(train_df.columns))
print("Test  columns:", list(test_df.columns))
print("Val   columns:", list(val_df.columns))

# ----------------------------
# Filter train & synthetic to metrics present in test (join on metric_name)
# ----------------------------
key = test_df[["metric_name"]].drop_duplicates()

train_mod = train_df.merge(key, on="metric_name", how="inner")
val_mod   = val_df.merge(key,   on="metric_name", how="inner")

val_mod = val_mod[val_mod['score'].astype(float) <= 8].reset_index(drop=True)


train_mod_path = "train_mod.json"
train_mod.to_json(train_mod_path, orient="records", force_ascii=False)
print("Saved filtered train data to:", train_mod_path)

train = train_mod.reset_index(drop=True)
val   = val_mod.reset_index(drop=True)

train_df = pd.concat([train, val], axis=0)
train_df = train_df.reset_index(drop=True)
# Out:
# Original Train shape: (5000, 5)
# Test shape          : (3638, 4)
# Synthetic data shape: (5500, 5)
# Train columns: ['metric_name', 'score', 'user_prompt', 'response', 'system_prompt']
# Test  columns: ['metric_name', 'user_prompt', 'response', 'system_prompt']
# Val   columns: ['metric_name', 'score', 'user_prompt', 'response', 'system_prompt']
# Saved filtered train data to: train_mod.json

# %%
# ----------------------------
# Downsample score = 9 points

target_n = 2000         # <<< choose how many points with score=9 you want to keep
# target_frac = 0.2     # <<< alternatively, keep a fraction instead of an absolute number

df9  = train_df[train_df["score"] == 9]
dfnz = train_df[train_df["score"] != 9]

# If using absolute count:
if len(df9) > target_n:
    df9_down = df9.sample(n=target_n, random_state=42)
else:
    df9_down = df9

# # If using fraction instead:
# df9_down = df9.sample(frac=target_frac, random_state=42)

# Combine back
train_df = pd.concat([dfnz, df9_down], axis=0).sample(frac=1, random_state=42).reset_index(drop=True)

print("Original score-9 count:", len(df9))
print("New score-9 count     :", sum(train_df["score"] == 9))
print("Final train shape     :", train_df.shape)
# Out:
# Original score-9 count: 3123
# New score-9 count     : 2000
# Final train shape     : (9377, 5)

# %%
print("Filtered Train shape:", train_df.shape)
print("Filtered Val shape  :", val_df.shape)

print("metric_emb shape:", metric_emb.shape)
print("# metric_names :", len(metric_name_list))
# Out:
# Filtered Train shape: (9377, 5)
# Filtered Val shape  : (5500, 5)
# metric_emb shape: (145, 768)
# # metric_names : 145

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(train_df['score'].values, bins=np.arange(-0.5, 11.5, 1))
plt.show()

# %%
from sklearn.model_selection import train_test_split
from collections import Counter
import numpy as np
import tqdm
print("Merged training shape (real + synthetic):", train_df.shape)

# Build stratification labels from scores (rounded 0..10)
scores_full = train_df["score"].astype(float).values
strat_labels = np.clip(np.round(scores_full), 0, 10).astype(int)

print("Score distribution (rounded) in merged train_df:")
print(Counter(strat_labels))

# Stratified split
train_split_df, val_split_df = train_test_split(
    train_df,
    test_size=0.2,
    random_state=42,
    stratify=strat_labels
)

print("Train split shape:", train_split_df.shape)
print("Val split shape  :", val_split_df.shape)

# Check distributions in each split
train_strat = np.clip(np.round(train_split_df["score"].astype(float).values), 0, 10).astype(int)
val_strat   = np.clip(np.round(val_split_df["score"].astype(float).values),   0, 10).astype(int)

print("\nTrain split score distribution (rounded):")
print(Counter(train_strat))
print("Val split score distribution (rounded):")
print(Counter(val_strat))

# From here on:
#   - use train_split_df for training embeddings/models
#   - use val_split_df   for validation
# Out:
# Merged training shape (real + synthetic): (9377, 5)
# Score distribution (rounded) in merged train_df:
# Counter({np.int64(9): 2000, np.int64(10): 1443, np.int64(8): 1059, np.int64(7): 895, np.int64(6): 845, np.int64(1): 569, np.int64(0): 567, np.int64(3): 560, np.int64(2): 532, np.int64(4): 484, np.int64(5): 423})
# Train split shape: (7501, 5)
# Val split shape  : (1876, 5)
#
# Train split score distribution (rounded):
# Counter({np.int64(9): 1600, np.int64(10): 1154, np.int64(8): 847, np.int64(7): 716, np.int64(6): 676, np.int64(1): 455, np.int64(0): 454, np.int64(3): 448, np.int64(2): 426, np.int64(4): 387, np.int64(5): 338})
# Val split score distribution (rounded):
# Counter({np.int64(9): 400, np.int64(10): 289, np.int64(8): 212, np.int64(7): 179, np.int64(6): 169, np.int64(1): 114, np.int64(0): 113, np.int64(3): 112, np.int64(2): 106, np.int64(4): 97, np.int64(5): 85})

# %%
# ----------------------------
# Install modeling libs
# ----------------------------
# !pip install -q transformers xgboost  # xgboost not used here but handy; remove if you want
# !pip install -q scikit-learn

from transformers import AutoTokenizer, AutoModel
import torch

from sklearn.kernel_ridge import KernelRidge
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# ======================================
# 1) Static metric embeddings (Gemma)
# ======================================
name_to_idx = {m: i for i, m in enumerate(metric_name_list)}

def get_metric_emb_for_series(s):
    idxs = s.map(name_to_idx).values
    return metric_emb[idxs]

train_metric_static = get_metric_emb_for_series(train_df["metric_name"])
test_metric_static  = get_metric_emb_for_series(test_df["metric_name"])
val_metric_static   = get_metric_emb_for_series(val_df["metric_name"])

print("Static metric emb train:", train_metric_static.shape)
print("Static metric emb test :", test_metric_static.shape)
print("Static metric emb val  :", val_metric_static.shape)
# Out:
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
# Static metric emb train: (9377, 768)
# Static metric emb test : (3638, 768)
# Static metric emb val  : (5500, 768)

# %%
print("Null values in cross_train:", np.isnan(train_metric_static).sum())
print("Null values in cross_test :", np.isnan(test_metric_static).sum())
print("Null values in cross_val  :", np.isnan(val_metric_static).sum())
# Store the embeddings so they can be shared with others
np.save("cross_train.npy", train_metric_static)
np.save("cross_test.npy", test_metric_static)
np.save("cross_val.npy", val_metric_static)

print("Saved cross encoder embeddings to .npy files. Share these files for easy reuse.")

# Example code to read (load) these embeddings again later:
cross_train_loaded = np.load("cross_train.npy")
cross_test_loaded = np.load("cross_test.npy")
cross_val_loaded = np.load("cross_val.npy")
# Out:
# Null values in cross_train: 0
# Null values in cross_test : 0
# Null values in cross_val  : 0
# Saved cross encoder embeddings to .npy files. Share these files for easy reuse.

# %%
# ======================================
# 2) Cross-encoder model (joint metric+convo)
# ======================================
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
from tqdm import tqdm

# Small multilingual model for speed
ce_model_name = "google/embeddinggemma-300m"

tokenizer = AutoTokenizer.from_pretrained(ce_model_name)
ce_model = AutoModel.from_pretrained(ce_model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ce_model.to(device)
ce_model.eval()

def build_pair_text(row):
    sp = (row.get("system_prompt")  or "") if "system_prompt"  in row else ""
    up = (row.get("user_prompt")    or "") if "user_prompt"    in row else ""
    rp = (row.get("response")       or "") if "response"       in row else ""
    m  = row.get("metric_name") or ""

    text = f"Metric: {m} [SEP] System: {sp} User: {up} Assistant: {rp}"
    return text


def encode_pairs(df, batch_size=16, max_length=256):
    all_embs = []
    n = len(df)

    # tqdm progress bar
    for start in tqdm(range(0, n, batch_size), desc="Encoding CE batches"):
        batch = df.iloc[start:start+batch_size]
        texts = [build_pair_text(row) for _, row in batch.iterrows()]

        enc = tokenizer(
            texts,
            padding=True,
            truncation=True,
            max_length=max_length,
            return_tensors="pt"
        ).to(device)

        with torch.no_grad():
            outputs = ce_model(**enc)
            # If model has pooler_output, use it; else CLS token
            if hasattr(outputs, "pooler_output") and outputs.pooler_output is not None:
                embs = outputs.pooler_output
            else:
                embs = outputs.last_hidden_state[:, 0, :]  # CLS token

        all_embs.append(embs.cpu().numpy())

    return np.vstack(all_embs)


print("Encoding cross-encoder embeddings (this may take a bit)...")
cross_train = encode_pairs(train_df, batch_size=16, max_length=256)
cross_test  = encode_pairs(test_df,  batch_size=16, max_length=256)
cross_val   = encode_pairs(val_df,   batch_size=16, max_length=256)

print("Cross-encoder emb train:", cross_train.shape)
print("Cross-encoder emb test :", cross_test.shape)
print("Cross-encoder emb val  :", cross_val.shape)
# Out:
# Encoding cross-encoder embeddings (this may take a bit)...
# ...
# Encoding CE batches: 100%|██████████| 344/344 [01:35<00:00,  3.60it/s]
# Cross-encoder emb train: (9377, 768)
# Cross-encoder emb test : (3638, 768)
# Cross-encoder emb val  : (5500, 768)

# %%
# ======================================
# 3) Build final feature matrices
#    Features = [Gemma metric emb | Cross-encoder joint emb]
# ======================================
X_train_real = np.hstack([train_metric_static, cross_train])
X_val_synth  = np.hstack([val_metric_static,   cross_val])
X_test_full  = np.hstack([test_metric_static,  cross_test])

print("X_train_real:", X_train_real.shape)
print("X_val_synth:", X_val_synth.shape)
print("X_test_full:", X_test_full.shape)

y_train_real = train_df["score"].astype(float).values
y_val_synth  = val_df["score"].astype(float).values

# Combine real + synthetic as full training pool
X_all = np.vstack([X_train_real, X_val_synth])
y_all = np.concatenate([y_train_real, y_val_synth])

print("Combined training shape:", X_all.shape, "Targets:", y_all.shape)
# Out:
# X_train_real: (9377, 1536)
# X_val_synth: (5500, 1536)
# X_test_full: (3638, 1536)
# Combined training shape: (14877, 1536) Targets: (14877,)

# %%
# ======================================
# 4) Train/validation split
# ======================================
from sklearn.preprocessing import RobustScaler

X_tr, X_val, y_tr, y_val = train_test_split(
    X_all,
    y_all,
    test_size=0.2,
    random_state=42,
)

print("Train split:", X_tr.shape, "Val split:", X_val.shape)
# Out:
# Train split: (11901, 1536) Val split: (2976, 1536)

# %% [markdown]
# ## Model

# %%
# ======================================
# 5) Kernel method: Kernel Ridge Regression (RBF)
#    Faster to tune than deep trees, expressive via kernel
# ======================================
krr_model = Pipeline([
    ("scaler", StandardScaler(with_mean=False)),
    ("krr", KernelRidge(kernel="rbf", alpha=1.0, gamma=None)),
])

krr_model.fit(X_tr, y_tr)
y_val_pred = krr_model.predict(X_val)
val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
print("Validation RMSE (KernelRidge RBF):", val_rmse)
# Out:
# Validation RMSE (KernelRidge RBF): 1.355076184580808

# %%
# ======================================
# 6) Train final model on all data and predict test
# ======================================
krr_model.fit(X_all, y_all)
test_preds = krr_model.predict(X_test_full)
test_preds = np.clip(test_preds, 0.0, 10.0)

# ======================================
# 7) Save submission: ID,score
# ======================================
submission = pd.DataFrame({
    "ID": np.arange(1, len(test_preds) + 1),
    "score": test_preds
})

# %%
out_path = "kernelridge.csv"
submission.to_csv(out_path, index=False)

print("Saved submission to:", out_path)
submission.head()

# %%
submission['score'].max()
# Out:
# np.float64(9.0)

# %% [markdown]
# ### CatBoost

# %%
# If needed:
# pip install catboost scikit-learn

from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# -----------------------------
# 1) Define and train model
# -----------------------------
cat_model = CatBoostRegressor(
    loss_function="RMSE",
    iterations=3000,
    learning_rate=0.02,
    depth=6,
    l2_leaf_reg=5.0,
    random_strength=0.8,
    bagging_temperature=0.4,
    subsample=0.8,
    rsm=0.8,              # feature subsampling
    random_seed=42,
    verbose=200
)

cat_model.fit(
    X_tr, y_tr,
    eval_set=(X_val, y_val),
    use_best_model=True
)


# -----------------------------
# 2) Evaluate on validation set
# -----------------------------
y_val_pred = cat_model.predict(X_val)

# Clip to [0, 10] since scores are bounded
y_val_pred = np.clip(y_val_pred, 0.0, 10.0)

rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
mae  = mean_absolute_error(y_val, y_val_pred)

print(f"CatBoost RMSE on val: {rmse:.4f}")
print(f"CatBoost MAE  on val: {mae:.4f}")
# Out:
# 0:	learn: 3.1124134	test: 3.1056309	best: 3.1056309 (0)	total: 274ms	remaining: 13m 41s
# 200:	learn: 1.2253207	test: 1.2258414	best: 1.2258414 (200)	total: 33.2s	remaining: 7m 42s
# 400:	learn: 1.1748092	test: 1.2007090	best: 1.2007090 (400)	total: 1m 5s	remaining: 7m 5s
# 600:	learn: 1.1202528	test: 1.1800944	best: 1.1800944 (600)	total: 1m 37s	remaining: 6m 30s
# 800:	learn: 1.0637870	test: 1.1564363	best: 1.1564363 (800)	total: 2m 9s	remaining: 5m 55s
# 1000:	learn: 1.0086374	test: 1.1332647	best: 1.1332647 (1000)	total: 2m 45s	remaining: 5m 30s
# 1200:	learn: 0.9595262	test: 1.1119723	best: 1.1119723 (1200)	total: 4m 39s	remaining: 6m 59s
# 1400:	learn: 0.9123010	test: 1.0909571	best: 1.0909571 (1400)	total: 6m 34s	remaining: 7m 30s
# 1600:	learn: 0.8690582	test: 1.0709134	best: 1.0709134 (1600)	total: 8m 18s	remaining: 7m 15s
# 1800:	learn: 0.8280215	test: 1.0513718	best: 1.0513718 (1800)	total: 10m 14s	remaining: 6m 49s
# ...

# %%
print(len(X_test_full))
y_pred = cat_model.predict(X_test_full)

# Clip to [0, 10] since scores are bounded
y_pred = np.clip(y_pred, 0.0, 10.0)
# Out:
# 3638

# %%
len(y_pred)
# Out:
# 3638

# %%
submission = pd.DataFrame({
    "ID": np.arange(1, len(y_pred) + 1),
    "score": y_pred
})

# %%
submission.head(10)
# Out:
#    ID     score
# 0   1  9.597235
# 1   2  8.891784
# 2   3  8.224055
# 3   4  8.457885
# 4   5  8.757814
# 5   6  6.363517
# 6   7  9.062770
# 7   8  9.399330
# 8   9  7.880936
# 9  10  9.426966

# %%
print(submission['score'].min())
print(submission['score'].mean())
print(submission['score'].max())
print(submission['score'].std())
# Out:
# 3.601552707727642
# 9.06283205859422
# 10.0
# 0.5642849614585957

# %%
out_path = "catboost.csv"
submission.to_csv(out_path, index=False)

print("Saved submission to:", out_path)
submission.head()
# Out:
# Saved submission to: catboost.csv
#    ID     score
# 0   1  9.597235
# 1   2  8.891784
# 2   3  8.224055
# 3   4  8.457885
# 4   5  8.757814

# %% [markdown]
# ## LightGBM

# %%
# If needed:
# pip install lightgbm scikit-learn

import lightgbm as lgb
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# -----------------------------
# 1) Train base LightGBM model
# -----------------------------
train_set = lgb.Dataset(X_tr, label=y_tr)
val_set   = lgb.Dataset(X_val, label=y_val)

params = {
    "objective": "regression",
    "metric": "rmse",
    "learning_rate": 0.02,
    "num_leaves": 31,
    "max_depth": -1,
    "feature_fraction": 0.8,
    "bagging_fraction": 0.8,
    "bagging_freq": 3,
    "lambda_l1": 0.1,
    "lambda_l2": 0.3,
    "min_data_in_leaf": 20,
    "verbose": -1,
    "seed": 42
}

lgb_model = lgb.train(
    params,
    train_set,
    valid_sets=[train_set, val_set],
    valid_names=["train", "val"],
    num_boost_round=5000
)

# -----------------------------
# 2) Stacking with Ridge
# -----------------------------
p_tr  = lgb_model.predict(X_tr, num_iteration=lgb_model.best_iteration)
p_val = lgb_model.predict(X_val, num_iteration=lgb_model.best_iteration)

ridge = Ridge(alpha=1.0, random_state=42)
ridge.fit(p_tr.reshape(-1, 1), y_tr)

y_val_pred = ridge.predict(p_val.reshape(-1, 1))
y_val_pred = np.clip(y_val_pred, 0.0, 10.0)

rmse = mean_squared_error(y_val, y_val_pred)**0.5
mae  = mean_absolute_error(y_val, y_val_pred)

print(f"LGBM+Ridge RMSE on val: {rmse:.4f}")
print(f"LGBM+Ridge MAE  on val: {mae:.4f}")
# Out:
# LGBM+Ridge RMSE on val: 0.7285
# LGBM+Ridge MAE  on val: 0.3359
